# %% [markdown]
# # Find the Best Location for Restaurant Near Contrad Hotel

# %% [markdown]
# ### In this project, I am going to select the best location for the restaurant near the University of Rochester. Therefore I will need the dataset of the restaurant venues near the university. After that, I will spot the location of current restaurant and visualize them on the map using the folium.

# %% [markdown]
# ### This project can help the enterprise to find the best location for their restaurant in the future.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'C4KFDVNCX3D3QBAJI0RSX3A332XYBWPL0Y2QCB0PRN5P1S0S' # your Foursquare ID
CLIENT_SECRET = 'QTPHKQT0FMLWUHTBL5Q0KDKKXUSVCJFLWJGME414GZAPWJOS' # your Foursquare Secret
VERSION = '20200704'
LIMIT = 50
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: C4KFDVNCX3D3QBAJI0RSX3A332XYBWPL0Y2QCB0PRN5P1S0S
# CLIENT_SECRET:QTPHKQT0FMLWUHTBL5Q0KDKKXUSVCJFLWJGME414GZAPWJOS

# %%
address = 'Elmwood Ave, Rochester, NY'
#'102 North End Ave, New York, NY'#
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.125455 -77.597612

# %%
search_query = 'restaurant'
radius = 50000
print(search_query + ' .... OK!')
# Out:
# restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=C4KFDVNCX3D3QBAJI0RSX3A332XYBWPL0Y2QCB0PRN5P1S0S&client_secret=QTPHKQT0FMLWUHTBL5Q0KDKKXUSVCJFLWJGME414GZAPWJOS&ll=43.125455,-77.597612&v=20200704&query=restaurant&radius=50000&limit=50'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f042ba2e116f90c6c784349'},
#  'response': {'venues': [{'id': '4babc69ff964a52098c83ae3',
#     'name': 'Golden Dynasty Chinese Restaurant',
#     'location': {'address': '1900 Clinton Ave S',
#      'lat': 43.120570772374364,
#      'lng': -77.59329450163801,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.120570772374364,
#        'lng': -77.59329450163801},
#       {'label': 'entrance', 'lat': 43.121319, 'lng': -77.59426}],
#      'distance': 647,
#      'postalCode': '14618',
#      'cc': 'US',
#      'city': 'Rochester',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1900 Clinton Ave S',
#       'Rochester, NY 14618',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                                       name  \
# 0  4babc69ff964a52098c83ae3          Golden Dynasty Chinese Restaurant
# 1  4bd77c760b779c74a75605a0           Lilu Cafe & Ethiopian Restaurant
# 2  501d4fb2e4b0cf97af8c62ef       The Restaurant At The Armory (TRATA)
# 3  5bb7cd73a35f460025d0173f  Peppapot Jamaican Restaurant and Catering
# 4  554f6797498ece2b655eb427                        Joey B's Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1594108980    False
# 1  [{'id': '4bf58dd8d48988d10a941735', 'name': 'E...  v-1594108980    False
# 2  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1594108980    False
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                               name                 categories  \
# 0                Golden Dynasty Chinese Restaurant         Chinese Restaurant
# 1                 Lilu Cafe & Ethiopian Restaurant       Ethiopian Restaurant
# 2             The Restaurant At The Armory (TRATA)        American Restaurant
# 3        Peppapot Jamaican Restaurant and Catering       Caribbean Restaurant
# 4                              Joey B's Restaurant                 Steakhouse
# 5                                   SEA Restaurant      Vietnamese Restaurant
# 6                                 Restaurant Depot            Warehouse Store
# 7                    Rong Cheng Chinese Restaurant         Chinese Restaurant
# 8                               Dac Hoa Restaurant      Vietnamese Restaurant
# 9                     LJ's Take Out & Restaurant 2       Caribbean Restaurant
# 10                   Chopsticks Chinese Restaurant         Chinese Restaurant
# ...

# %%
dataframe_filtered.name
# Out:
# 0                  Golden Dynasty Chinese Restaurant
# 1                   Lilu Cafe & Ethiopian Restaurant
# 2               The Restaurant At The Armory (TRATA)
# 3          Peppapot Jamaican Restaurant and Catering
# 4                                Joey B's Restaurant
# 5                                     SEA Restaurant
# 6                                   Restaurant Depot
# 7                      Rong Cheng Chinese Restaurant
# 8                                 Dac Hoa Restaurant
# 9                       LJ's Take Out & Restaurant 2
# 10                     Chopsticks Chinese Restaurant
# 11    Amore Italian Restaurant & Wine Bar by Wegmans
# 12                        LJ's Take Out & Restaurant
# 13                          Youngs Korean Restaurant
# 14                               Rooney's Restaurant
# 15                                Akwaaba Restaurant
# 16                               Restaurant Fiorella
# 17                       Zemeta Ethiopian Restaurant
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## As is shown on the map, we should pick up the most popular location around the
# ## *Monroe Avenue* --------  Yellow point on the map

# %%
address = 'Monroe Avenue, Rochester, NY'
#'102 North End Ave, New York, NY'#
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.1471568 -77.5947806

# %%
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='yellow',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'yellow',
    fill_opacity = 0.6
).add_to(venues_map)
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
